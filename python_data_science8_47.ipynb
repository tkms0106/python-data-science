# %% [markdown]
# <a href="https://colab.research.google.com/github/tkms0106/python-data-science/blob/master/python_data_science8_47.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from numpy.random import randn

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
dataset1 = randn(100)

# %%
plt.hist(dataset1)
# Out:
# (array([ 3.,  3., 12., 14., 18., 22., 14.,  9.,  3.,  2.]),
#  array([-2.38760444, -1.90680903, -1.42601363, -0.94521822, -0.46442282,
#          0.01637259,  0.49716799,  0.9779634 ,  1.4587588 ,  1.93955421,
#          2.42034961]),
#  <a list of 10 Patch objects>)

# %%
dataset2 = randn(80)

# %%
plt.hist(dataset2, color='indianred')
# Out:
# (array([ 3.,  2.,  7.,  4., 17., 11., 15., 13.,  5.,  3.]),
#  array([-2.14786409, -1.7303918 , -1.3129195 , -0.89544721, -0.47797492,
#         -0.06050262,  0.35696967,  0.77444196,  1.19191426,  1.60938655,
#          2.02685884]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(dataset1, normed=True)
# Out:
# (array([0.0623966 , 0.0623966 , 0.24958641, 0.29118415, 0.37437962,
#         0.45757509, 0.29118415, 0.18718981, 0.0623966 , 0.04159774]),
#  array([-2.38760444, -1.90680903, -1.42601363, -0.94521822, -0.46442282,
#          0.01637259,  0.49716799,  0.9779634 ,  1.4587588 ,  1.93955421,
#          2.42034961]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(dataset1, normed=True, alpha=0.5, bins=20)
plt.hist(dataset2, normed=True, alpha=0.5, bins=20, color='indianred')
# Out:
# (array([0.11976843, 0.05988421, 0.        , 0.11976843, 0.11976843,
#         0.29942107, 0.11976843, 0.11976843, 0.4191895 , 0.59884214,
#         0.47907371, 0.17965264, 0.65872635, 0.23953685, 0.47907371,
#         0.29942107, 0.17965264, 0.11976843, 0.        , 0.17965264]),
#  array([-2.14786409, -1.93912795, -1.7303918 , -1.52165565, -1.3129195 ,
#         -1.10418336, -0.89544721, -0.68671106, -0.47797492, -0.26923877,
#         -0.06050262,  0.14823352,  0.35696967,  0.56570582,  0.77444196,
#          0.98317811,  1.19191426,  1.4006504 ,  1.60938655,  1.8181227 ,
#          2.02685884]),
#  <a list of 20 Patch objects>)

# %%
data1 = randn(1000)
data2 = randn(1000)

# %%
sns.jointplot(data1, data2)

# %%
sns.jointplot(data1, data2, kind='hex')
